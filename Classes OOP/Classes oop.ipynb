# %% [markdown]
# ### Object Oriented Programming
# Class - is like a blueprint
#
# Object - a specific instance of class

# %%
a = 4 print(type(a))
# Out:
#   Cell In[1], line 1
#     a = 4 print(type(a))
#           ^
# SyntaxError: invalid syntax

# %%
a= 4
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# ### in above code variable a is object of class integer (int)

# %%
b = 6.7
print(type(b))
# Out:
# <class 'float'>

# %%
c = "ETLHive"
print(type(c))
# Out:
# <class 'str'>

# %%
d = False
print(type(d))
# Out:
# <class 'bool'>

# %%
e = [1, 2, 3, 4, 5]
print(type(e))
# Out:
# <class 'list'>

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
import pandas as pd

# %%
df = pd.read_csv("50_Startups.csv")
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
Attributes of class dataframe
# Out:
#   Cell In[11], line 1
#     Attributes of class dataframe
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Attributes of class dataframe

# %%
df.shape
# Out:
# (50, 5)

# %%
df.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'STATE', 'PROFIT'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df.dtypes
# Out:
# RND       float64
# ADMIN     float64
# MKT       float64
# STATE      object
# PROFIT    float64
# dtype: object

# %% [markdown]
# ### Functions (Method) inside Dataframe
# function always have () in end

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.sort_values(by=["STATE", "PROFIT"], ascending=False)
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 15  114523.61  122616.84  261776.23    New York  129917.04
# 17   94657.16  145077.58  282574.31    New York  125370.37
# 19   86419.70  153514.11       0.00    New York  122776.86
# 21   78389.47  153773.43  299737.29    New York  111313.02
# 24   77044.01   99281.34  140574.81    New York  108552.04
# 27   72107.60  127864.55  353183.81    New York  105008.31
# 29   65605.48  153032.06  107138.38    New York  101004.64
# 31   61136.38  152701.92   88218.23    New York   97483.56
# 35   46014.02   85047.44  205517.64    New York   96479.51
# 38   20229.59   65947.93  185265.10    New York   81229.06
# 43   15505.73  127382.30   35534.17    New York   69758.98
# ...

# %%
df.groupby(by="STATE").agg({"PROFIT":"mean"})
# Out:
#                    PROFIT
# STATE
# California  103905.175294
# Florida     118774.024375
# New York    113756.446471

# %% [markdown]
# ### in above df is object of Class Dataframe
# How to create user defined class
# image.png

# %% [markdown]
# ### ![image.png](attachment:image.png)

# %% [markdown]
# ### ![image.png](attachment:image.png)

# %%
class Person:

    # Create a constructor function
    def  __init__(self, name:str, age:int, gender:str, occupation:str):
        self.name = name
        self.age = age
        self.gender = gender
        self.occupation = occupation

    # Create functions for class person
    def talk(self):
        print(f"Hi there my name is : {self.name}")
        print(f"I am currently {self.age} years old")
        print(f"I am a {self.gender}")
        print(f"I work as {self.occupation}")

# %%
p1 = Person(name = "Sarthak", age = 23, gender= "male", occupation= "Engineer")
print(type(p1))
# Out:
# <class '__main__.Person'>

# %% [markdown]
# ### __main__ referes to current file you are working in
# Attributes of class person - name, age, gender, occupation

# %%
p1.name
# Out:
# 'Sarthak'

# %%
'Sarthak'
# Out:
# 'Sarthak'

# %%
p1.age
# Out:
# 23

# %%
p1.gender
# Out:
# 'male'

# %%
p1.occupation
# Out:
# 'Engineer'

# %% [markdown]
# ### Method of class person - talk

# %%
p1.talk()
# Out:
# Hi there my name is : Sarthak
# I am currently 23 years old
# I am a male
# I work as Engineer

# %%
Updating attribute for class
# Out:
#   Cell In[27], line 1
#     Updating attribute for class
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Updating attribute for class

# %%
p1.age
# Out:
# 23

# %%
p1.age = 24

# %%
<__main__.Person at 0x1f751414a70>
# Out:
#   Cell In[30], line 1
# ...
#     ^
# SyntaxError: invalid syntax

# %%
p1

# %%
p1.talk()
# Out:
# Hi there my name is : Sarthak
# I am currently 24 years old
# I am a male
# I work as Engineer

# %%
p1.age
# Out:
# 24

# %% [markdown]
# ### Declaring person2

# %%
p2 = Person("Aditi", 20, "female", "HR")
print(type(p2))
# Out:
# <class '__main__.Person'>

# %%
<class '__main__.Person'>
# Out:
#   Cell In[35], line 1
#     <class '__main__.Person'>
#     ^
# SyntaxError: invalid syntax

# %%
p2 = Person("Aditi", 20, "female", "HR")
print(type(p2))
<class '__main__.Person'>
# Out:
#   Cell In[36], line 3
#     <class '__main__.Person'>
#     ^
# SyntaxError: invalid syntax

# %%
p2 = Person("Aditi", 20, "female", "HR")
print(type(p2))
# Out:
# <class '__main__.Person'>

# %%
p2

# %%
<__main__.Person at 0x1f752292ab0>
# Out:
#   Cell In[39], line 1
# ...
#     ^
# SyntaxError: invalid syntax

# %%
p2.name
# Out:
# 'Aditi'

# %%
p2.age
# Out:
# 20

# %%
p2.gender
# Out:
# 'female'

# %%
p2.occupation
# Out:
# 'HR'

# %%
p2.talk()
# Out:
# Hi there my name is : Aditi
# I am currently 20 years old
# I am a female
# I work as HR

# %%
p2.occupation = "Data Scientist"

# %%
p2.occupation
# Out:
# 'Data Scientist'

# %%
p2.talk()
# Out:
# Hi there my name is : Aditi
# I am currently 20 years old
# I am a female
# I work as Data Scientist
