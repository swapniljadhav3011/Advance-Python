# %% [markdown]
# ### Exception Handling
# Whenver you invalid Operations in python eception will occur
#
# ![image.png](attachment:image.png)

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
a= "23" 
type(a)
# Out:
# str

# %%
b = int(a)
type(b)
# Out:
# int

# %% [markdown]
# Division Without exception handling

# %%
def division():
    num = float(input("Please enter the numerator : "))
    den = float(input("Please enter the Denominator : "))
    div = num/den
    print(f"Division of {num} and {den} is {div}")
    return div

# %%
division()
# Out:
# Division of 12.0 and 4.0 is 3.0
# 3.0

# %%
division()
# Out:
# Division of 365.0 and 12.0 is 30.416666666666668
# 30.416666666666668

# %%
division()
print("program completed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 division()
#       2 print("program completed")
#
# Cell In[5], line 2, in division()
#       1 def division():
# ----> 2     num = float(input("Please enter the numerator : "))
#       3     den = float(input("Please enter the Denominator : "))
#       4     div = num/den
#
# ValueError: could not convert string to float: 'yes'

# %% [markdown]
# Generic Exception handling

# %%
def division2():
    try:
        num = float(input("Please enter numerator : "))
        den = float(input("Please enter denominator : "))
        div = num/den
        print(f"Division of {num} and {den} is {div}")
        return div
    except Exception as e:
        print(f"Exception Occured {e}")

# %%
division2()
print("Hello All")
# Out:
# Division of 111.0 and 11.0 is 10.090909090909092
# Hello All

# %%
# Denominator is 0
division2()
print("Program Completed")
# Out:
# Exception Occured float division by zero
# Program Completed

# %%
# Blank input
division2()
print(3*4)
# Out:
# Exception Occured could not convert string to float: ''
# 12

# %% [markdown]
# Detailed Exception handling

# %%
def division3():
    try:
        num = float(input("Please enter numerator : "))
        den = float(input("Please enter denominator : "))
        div = num/den 
        print(f"Division of {num} and {den} is {div}")
        return div
    except ZeroDivisionError:
        print("Denominator cannot be 0")
    except ValueError:
        print("Please enter valid inputs , blank input not allowed")
    except Exception as e:
        print(f"Unexpected Error Occured : {e}")

# %%
division3()
# Out:
# Division of 12.0 and 3.0 is 4.0
# 4.0

# %%
# Divide by 0
division3()
# Out:
# Division of 0.0 and 5.0 is 0.0
# 0.0

# %%
# Invalid input abc
division3()
# Out:
# Please enter valid inputs , blank input not allowed

# %%
# Blank input
division3()
# Out:
# Please enter valid inputs , blank input not allowed

# %% [markdown]
# Raise custom exceptions

# %%
age = int(input("Please enter age in years : "))
print(f"Age entered : {age}")
# Out:
# Age entered : 52

# %%
age = int(input("Please enter age in years : "))
print(f"Age entered : {age}")
# Out:
# Age entered : 100

# %%
def valid_age():
    try:
        age = int(input("Please enter age between 0 to 120 : "))
        if age < 0 or age > 120:
            raise ValueError("Age should be between 0 and 120")
        else:
            return age
    except Exception as e:
        print(f"Exception occured : {e}")

# %%
age = valid_age()
print(f"Age entered : {age}")
# Out:
# Age entered : 20

# %%
# Enter negative age
age = valid_age()
print(f"Age Entered : {age}")
# Out:
# Exception occured : Age should be between 0 and 120
# Age Entered : None

# %%
# Enter age as 200
age = valid_age()
print(f"Age entered : {age}")
# Out:
# Exception occured : Age should be between 0 and 120
# Age entered : None

# %%
age

# %%
age = valid_age()
print(f"Age entered : {age}")
# Out:
# Age entered : 45

# %%
age
# Out:
# 45

# %%
# Invalid input abc
age = valid_age()
print(f"Age entered : {age}")
# Out:
# Exception occured : invalid literal for int() with base 10: 'kjn'
# Age entered : None

# %%
age

# %% [markdown]
# ### Exception handling blocks
#
# 1.try - Code which you want to execute
# 2.except - If any exception occurs this block
# will be executed
# 3.else - will execute only if try block is successful
# 4.finally - this block will always execute

# %%
from math import sqrt

# %%
sqrt(25)
# Out:
# 5.0

# %%
sqrt(-12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sqrt(-12)
#
# ValueError: math domain error

# %%
s1 = square_root()
# Out:
# Exception occured : could not convert string to float: ''
# The finally block is always executed

# %%
def square_root():
    try:
        n = float(input("Please enter positive number : "))
        s = sqrt(n)
    except Exception as e:
        print(f"Exception occured : {e}")
    else:
        print(f"Square root of number {n} is {s:.4f}")
        return s
    finally:
        print("The finally block is always executed")

# %%
s1 = square_root()
# Out:
# Square root of number 64.0 is 8.0000
# The finally block is always executed

# %%
s1
# Out:
# 8.0

# %%
# Negative number -23
s2 = square_root()
# Out:
# Exception occured : could not convert string to float: 's2'
# The finally block is always executed

# %%
# Invalid input
s3 = square_root()
# Out:
# Exception occured : could not convert string to float: 'abc'
# The finally block is always executed

# %%
print(s3)
# Out:
# None

# %%
try:
    num = float(input("Please enter Numerator : "))
    den = float(input("Please enter Denominator : "))
    div = num/den
except Exception as e:
    print(f"Exception Occured : {e}")
else:
    print(f"Division of {num} by {den} is {div:.4f}")
finally:
    print("Thank you")
# Out:
# Exception Occured : could not convert string to float: 'abd'
# Thank you
